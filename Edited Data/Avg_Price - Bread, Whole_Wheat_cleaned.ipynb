# %%
import pandas as pd
import numpy as np

# %%
#Load in raw data to dataframe
file_path = "Avg_Price - Bread, Whole_Wheat.csv"
wheat_df = pd.read_csv(file_path)
wheat_df
# Out:
#            DATE APU0000702212
# 0    1980-01-01         0.715
# 1    1980-02-01         0.723
# 2    1980-03-01         0.696
# 3    1980-04-01         0.713
# 4    1980-05-01         0.720
# ..          ...           ...
# 512  2022-09-01         2.362
# 513  2022-10-01         2.386
# 514  2022-11-01         2.419
# 515  2022-12-01         2.419
# 516  2023-01-01         2.451
#
# [517 rows x 2 columns]

# %%
#Rename the price column
wheat_df.rename(mapper={"APU0000702212" : "Price_(USD/LB)"}, axis=1, inplace=True)
wheat_df.head()
# Out:
#          DATE Price_(USD/LB)
# 0  1980-01-01          0.715
# 1  1980-02-01          0.723
# 2  1980-03-01          0.696
# 3  1980-04-01          0.713
# 4  1980-05-01          0.720

# %%
#price is $USD/lb

# %%
#View datatypes to see what needs to be changed
wheat_df.dtypes
# Out:
# DATE              object
# Price_(USD/LB)    object
# dtype: object

# %%
#check if there are null values
wheat_df.isnull().sum()
# Out:
# DATE              0
# Price_(USD/LB)    0
# dtype: int64

# %%
#Change DATE to datetime
wheat_df['DATE'] = pd.to_datetime(wheat_df["DATE"], format="%Y-%m-%d")
wheat_df.head()
# Out:
#         DATE Price_(USD/LB)
# 0 1980-01-01          0.715
# 1 1980-02-01          0.723
# 2 1980-03-01          0.696
# 3 1980-04-01          0.713
# 4 1980-05-01          0.720

# %%
#View datatypes to confirm change
wheat_df.dtypes
# Out:
# DATE              datetime64[ns]
# Price_(USD/LB)            object
# dtype: object

# %%
#Change Price column to float
wheat_df["Price_(USD/LB)"] = wheat_df["Price_(USD/LB)"].astype(float)
wheat_df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_30868\189976344.py in <module>
#       1 #Change Price column to float
# ----> 2 wheat_df["Price_(USD/LB)"] = wheat_df["Price_(USD/LB)"].astype(float)
#       3 wheat_df.head()
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5813         else:
#    5814             # else, only a single dtype is given
# -> 5815             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5816             return self._constructor(new_data).__finalize__(self, method="astype")
#    5817
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     416
#     417     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# ...

# %%
#vieww Price values
print(wheat_df["Price_(USD/LB)"].values)
# Out:
# ['0.715' '0.723' '0.696' '0.713' '0.720' '0.726' '0.735' '0.741' '0.723'
#  '0.739' '0.737' '0.747' '0.759' '0.750' '0.767' '0.753' '0.762' '0.766'
#  '0.781' '0.787' '0.791' '0.785' '0.798' '0.808' '0.811' '0.811' '0.826'
#  '0.822' '0.818' '0.812' '0.810' '0.804' '0.814' '0.821' '0.818' '0.830'
#  '0.826' '0.824' '0.831' '0.831' '0.837' '0.831' '0.840' '0.850' '0.860'
#  '0.859' '0.854' '0.870' '0.891' '0.889' '0.876' '0.886' '0.888' '0.895'
#  '0.876' '0.851' '0.859' '0.863' '0.879' '0.856' '0.857' '0.850' '0.853'
#  '0.860' '0.855' '0.852' '0.865' '0.863' '0.864' '0.862' '0.867' '0.863'
#  '0.865' '0.850' '0.850' '0.852' '0.859' '0.873' '0.874' '0.875' '0.876'
#  '0.879' '0.885' '0.876' '0.866' '0.876' '0.866' '0.885' '0.884' '0.879'
#  '0.857' '0.875' '0.875' '0.900' '0.896' '0.900' '0.915' '0.938' '0.936'
#  '.' '.' '.' '.' '.' '.' '.' '.' '.' '.' '.' '.' '.' '.' '.' '.' '.' '.'
#  '.' '.' '.' '.' '.' '.' '.' '.' '.' '.' '.' '.' '.' '.' '.' '1.102'
# ...

# %%
#Identify problematic values
print(wheat_df.loc[wheat_df['Price_(USD/LB)'] == "."])
# Out:
#           DATE Price_(USD/LB)
# 99  1988-04-01              .
# 100 1988-05-01              .
# 101 1988-06-01              .
# 102 1988-07-01              .
# 103 1988-08-01              .
# 104 1988-09-01              .
# 105 1988-10-01              .
# 106 1988-11-01              .
# 107 1988-12-01              .
# 108 1989-01-01              .
# 109 1989-02-01              .
# 110 1989-03-01              .
# 111 1989-04-01              .
# 112 1989-05-01              .
# 113 1989-06-01              .
# 114 1989-07-01              .
# 115 1989-08-01              .
# 116 1989-09-01              .
# 117 1989-10-01              .
# 118 1989-11-01              .
# 119 1989-12-01              .
# 120 1990-01-01              .
# 121 1990-02-01              .
# 122 1990-03-01              .
# 123 1990-04-01              .
# 124 1990-05-01              .
# 125 1990-06-01              .
# 126 1990-07-01              .
# 127 1990-08-01              .
# 128 1990-09-01              .
# ...

# %%
#Identify prblem range (example)
wheat_df.iloc[99:132]
# Out:
#           DATE Price_(USD/LB)
# 99  1988-04-01              .
# 100 1988-05-01              .
# 101 1988-06-01              .
# 102 1988-07-01              .
# 103 1988-08-01              .
# 104 1988-09-01              .
# 105 1988-10-01              .
# 106 1988-11-01              .
# 107 1988-12-01              .
# 108 1989-01-01              .
# 109 1989-02-01              .
# 110 1989-03-01              .
# 111 1989-04-01              .
# 112 1989-05-01              .
# 113 1989-06-01              .
# 114 1989-07-01              .
# 115 1989-08-01              .
# 116 1989-09-01              .
# 117 1989-10-01              .
# 118 1989-11-01              .
# 119 1989-12-01              .
# 120 1990-01-01              .
# 121 1990-02-01              .
# 122 1990-03-01              .
# 123 1990-04-01              .
# 124 1990-05-01              .
# 125 1990-06-01              .
# 126 1990-07-01              .
# 127 1990-08-01              .
# 128 1990-09-01              .
# ...

# %%
#Create avg values based on values immeadiately preceeding and post problem instance to use as replacement for "."
temp_avg1 = (float(wheat_df["Price_(USD/LB)"].values[132]) + float(wheat_df["Price_(USD/LB)"].values[98])) / 2
temp_avg2 = (float(wheat_df["Price_(USD/LB)"].values[280]) + float(wheat_df["Price_(USD/LB)"].values[282])) / 2
temp_avg3 = (float(wheat_df["Price_(USD/LB)"].values[285]) + float(wheat_df["Price_(USD/LB)"].values[290])) / 2
temp_avg4 = (float(wheat_df["Price_(USD/LB)"].values[291]) + float(wheat_df["Price_(USD/LB)"].values[297])) / 2

# %%
#print temp_avg_values
print(temp_avg1, temp_avg2, temp_avg3, temp_avg4)
# Out:
# 1.0190000000000001 1.4465 1.3205 1.3565

# %%
#replace problematic ranges with calculated avg values 
wheat_df["Price_(USD/LB)"][99:132] = wheat_df["Price_(USD/LB)"][99:132].replace(".", temp_avg1)
wheat_df[98:133]
# Out:
# C:\Users\jhillman\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#           DATE Price_(USD/LB)
# 98  1988-03-01          0.936
# 99  1988-04-01          1.019
# 100 1988-05-01          1.019
# 101 1988-06-01          1.019
# 102 1988-07-01          1.019
# 103 1988-08-01          1.019
# 104 1988-09-01          1.019
# 105 1988-10-01          1.019
# 106 1988-11-01          1.019
# 107 1988-12-01          1.019
# 108 1989-01-01          1.019
# 109 1989-02-01          1.019
# 110 1989-03-01          1.019
# 111 1989-04-01          1.019
# 112 1989-05-01          1.019
# 113 1989-06-01          1.019
# 114 1989-07-01          1.019
# 115 1989-08-01          1.019
# 116 1989-09-01          1.019
# 117 1989-10-01          1.019
# ...

# %%
#replace problematic ranges with calculated avg values 
wheat_df.at[281,"Price_(USD/LB)"] = temp_avg2
wheat_df[280:283]
# Out:
#           DATE Price_(USD/LB)
# 280 2003-05-01          1.447
# 281 2003-06-01         1.4465
# 282 2003-07-01          1.446

# %%
#replace problematic ranges with calculated avg values 
wheat_df["Price_(USD/LB)"][286:290] = wheat_df["Price_(USD/LB)"][286:290].replace(".", temp_avg3)
wheat_df[285:291]
# Out:
# C:\Users\jhillman\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#           DATE Price_(USD/LB)
# 285 2003-10-01          1.362
# 286 2003-11-01         1.3205
# 287 2003-12-01         1.3205
# 288 2004-01-01         1.3205
# 289 2004-02-01         1.3205
# 290 2004-03-01          1.279

# %%
#replace problematic ranges with calculated avg values 
wheat_df["Price_(USD/LB)"][292:297] = wheat_df["Price_(USD/LB)"][292:297].replace(".", temp_avg4)
wheat_df[291:298]
# Out:
# C:\Users\jhillman\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#           DATE Price_(USD/LB)
# 291 2004-04-01          1.341
# 292 2004-05-01         1.3565
# 293 2004-06-01         1.3565
# 294 2004-07-01         1.3565
# 295 2004-08-01         1.3565
# 296 2004-09-01         1.3565
# 297 2004-10-01          1.372

# %%
#check for any remaining "." values 
wheat_df.loc[wheat_df["Price_(USD/LB)"] == "."]
# Out:
# Empty DataFrame
# Columns: [DATE, Price_(USD/LB)]
# Index: []

# %%
#check datatypes
wheat_df.dtypes
# Out:
# DATE              datetime64[ns]
# Price_(USD/LB)            object
# dtype: object

# %%
#change Price column to float
wheat_df["Price_(USD/LB)"] = wheat_df["Price_(USD/LB)"].astype(float)

# %%
#confirm change of datatype
wheat_df.dtypes
# Out:
# DATE              datetime64[ns]
# Price_(USD/LB)           float64
# dtype: object

# %%
#round price values to (3) decimal points
wheat_df["Price_(USD/LB)"] = wheat_df["Price_(USD/LB)"].round(decimals=3)

# %%
#confirm crounding of points
print(wheat_df[98:133], wheat_df[280:283], wheat_df[285:291], wheat_df[291:298])
# Out:
#           DATE  Price_(USD/LB)
# 98  1988-03-01           0.936
# 99  1988-04-01           1.019
# 100 1988-05-01           1.019
# 101 1988-06-01           1.019
# 102 1988-07-01           1.019
# 103 1988-08-01           1.019
# 104 1988-09-01           1.019
# 105 1988-10-01           1.019
# 106 1988-11-01           1.019
# 107 1988-12-01           1.019
# 108 1989-01-01           1.019
# 109 1989-02-01           1.019
# 110 1989-03-01           1.019
# 111 1989-04-01           1.019
# 112 1989-05-01           1.019
# 113 1989-06-01           1.019
# 114 1989-07-01           1.019
# 115 1989-08-01           1.019
# 116 1989-09-01           1.019
# 117 1989-10-01           1.019
# 118 1989-11-01           1.019
# 119 1989-12-01           1.019
# 120 1990-01-01           1.019
# 121 1990-02-01           1.019
# 122 1990-03-01           1.019
# 123 1990-04-01           1.019
# 124 1990-05-01           1.019
# 125 1990-06-01           1.019
# 126 1990-07-01           1.019
# ...

# %%
#create cleaned df of data post 1990
avg_price_wheat_cleaned = wheat_df[wheat_df["DATE"] >= "1990-01-01"]
avg_price_wheat_cleaned
# Out:
#           DATE  Price_(USD/LB)
# 120 1990-01-01           1.019
# 121 1990-02-01           1.019
# 122 1990-03-01           1.019
# 123 1990-04-01           1.019
# 124 1990-05-01           1.019
# ..         ...             ...
# 512 2022-09-01           2.362
# 513 2022-10-01           2.386
# 514 2022-11-01           2.419
# 515 2022-12-01           2.419
# 516 2023-01-01           2.451
#
# [397 rows x 2 columns]

# %%
# rename "DATE" column to "date_time" per team data process in README
avg_price_wheat_cleaned.rename(mapper={"DATE" : "date_time"}, axis=1, inplace=True)
avg_price_wheat_cleaned.head()
# Out:
# C:\Users\jhillman\anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py:5047: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#      date_time  Price_(USD/LB)
# 120 1990-01-01           1.019
# 121 1990-02-01           1.019
# 122 1990-03-01           1.019
# 123 1990-04-01           1.019
# 124 1990-05-01           1.019

# %%
# Calculate percent change
avg_price_wheat_cleaned["Pct_Change"] = avg_price_wheat_cleaned["Price_(USD/LB)"].pct_change()
avg_price_wheat_cleaned.head(30)
# Out:
# C:\Users\jhillman\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#      date_time  Price_(USD/LB)  Pct_Change
# 120 1990-01-01           1.019         NaN
# 121 1990-02-01           1.019    0.000000
# 122 1990-03-01           1.019    0.000000
# 123 1990-04-01           1.019    0.000000
# 124 1990-05-01           1.019    0.000000
# 125 1990-06-01           1.019    0.000000
# 126 1990-07-01           1.019    0.000000
# 127 1990-08-01           1.019    0.000000
# 128 1990-09-01           1.019    0.000000
# 129 1990-10-01           1.019    0.000000
# 130 1990-11-01           1.019    0.000000
# 131 1990-12-01           1.019    0.000000
# ...

# %%
# Store new DF as new csv file
output_path = "Output/avg_price_wheat_cleaned.csv"
cleaned_wheat_df.to_csv(output_path)
