# %% [markdown]
# ## Purpose
# This notebook creates a new dataset where each row contains price data from its month and DJIA price movement data form the following month. For example, the row with the price of milk from May 2004 will contain the price movement of the DJIA for June 2004.

# %%
import pandas as pd

# %%
price_df = pd.read_csv("../same_date/ML1_data.csv")
price_df.head()
# Out:
#     date_time  Beef $/LB  Beef_Pct_Change  Wheat_Price  CPI_Price  \
# 0  1995-07-01      1.365         0.024006        1.147      138.2
# 1  1995-08-01      1.328        -0.027106        1.161      138.8
# 2  1995-09-01      1.376         0.036145        1.159      139.5
# 3  1995-10-01      1.371        -0.003634        1.175      140.6
# 4  1995-11-01      1.368        -0.002188        1.169      141.0
#
#    Milk Cost per Gallon  DJIA_change
# 0                 2.477            1
# 1                 2.482            0
# 2                 2.459            1
# 3                 2.473            0
# 4                 2.493            1

# %%
# set date_time as index
price_df = price_df.set_index("date_time")
price_df.head()
# Out:
#             Beef $/LB  Beef_Pct_Change  Wheat_Price  CPI_Price  \
# date_time
# 1995-07-01      1.365         0.024006        1.147      138.2
# 1995-08-01      1.328        -0.027106        1.161      138.8
# 1995-09-01      1.376         0.036145        1.159      139.5
# 1995-10-01      1.371        -0.003634        1.175      140.6
# 1995-11-01      1.368        -0.002188        1.169      141.0
#
#             Milk Cost per Gallon  DJIA_change
# date_time
# 1995-07-01                 2.477            1
# 1995-08-01                 2.482            0
# 1995-09-01                 2.459            1
# 1995-10-01                 2.473            0
# 1995-11-01                 2.493            1

# %%
# Move all the DJIA data up one month

# Save values as list
djia_list = list(price_df["DJIA_change"].values)

# Create new list
new_djia = []

# Use for loop to make each list index equivalent to the one after it
for i in range(1, len(djia_list)):
    new_djia.append(djia_list[i])

# We do not have data for the month following the last month in the dataset
# So we will insert this placeholder and drop the row later
new_djia.append("NA")

price_df["Next_Month_DJIA_Change"] = new_djia

price_df.head()
# Out:
#             Beef $/LB  Beef_Pct_Change  Wheat_Price  CPI_Price  \
# date_time
# 1995-07-01      1.365         0.024006        1.147      138.2
# 1995-08-01      1.328        -0.027106        1.161      138.8
# 1995-09-01      1.376         0.036145        1.159      139.5
# 1995-10-01      1.371        -0.003634        1.175      140.6
# 1995-11-01      1.368        -0.002188        1.169      141.0
#
#             Milk Cost per Gallon  DJIA_change Next_Month_DJIA_Change
# date_time
# 1995-07-01                 2.477            1                      0
# 1995-08-01                 2.482            0                      1
# 1995-09-01                 2.459            1                      0
# 1995-10-01                 2.473            0                      1
# 1995-11-01                 2.493            1                      1

# %%
# Check tail
price_df.tail(10)
# Out:
#             Beef $/LB  Beef_Pct_Change  Wheat_Price  CPI_Price  \
# date_time
# 2022-04-01      4.916         0.033424        2.145    310.280
# 2022-05-01      4.794        -0.024817        2.220    313.944
# 2022-06-01      4.889         0.019816        2.230    314.138
# 2022-07-01      4.893         0.000818        2.316    315.797
# 2022-08-01      4.937         0.008992        2.298    317.433
# 2022-09-01      4.862        -0.015191        2.362    318.374
# 2022-10-01      4.836        -0.005348        2.386    319.917
# 2022-11-01      4.853         0.003515        2.419    320.034
# 2022-12-01      4.800        -0.010921        2.419    322.507
# 2023-01-01      4.791        -0.001875        2.451    324.815
#
#             Milk Cost per Gallon  DJIA_change Next_Month_DJIA_Change
# date_time
# 2022-04-01                 4.012            0                      1
# 2022-05-01                 4.204            1                      0
# 2022-06-01                 4.153            0                      1
# 2022-07-01                 4.156            1                      0
# 2022-08-01                 4.194            0                      0
# 2022-09-01                 4.181            0                      1
# 2022-10-01                 4.184            1                      1
# 2022-11-01                 4.218            1                      0
# 2022-12-01                 4.211            0                      1
# 2023-01-01                 4.204            1                     NA

# %%
# Drop last row because we don't have data on the future
price_df = price_df.drop("2023-01-01", axis=0)
price_df.tail(10)
# Out:
#             Beef $/LB  Beef_Pct_Change  Wheat_Price  CPI_Price  \
# date_time
# 2022-03-01      4.757         0.027430        2.121    306.799
# 2022-04-01      4.916         0.033424        2.145    310.280
# 2022-05-01      4.794        -0.024817        2.220    313.944
# 2022-06-01      4.889         0.019816        2.230    314.138
# 2022-07-01      4.893         0.000818        2.316    315.797
# 2022-08-01      4.937         0.008992        2.298    317.433
# 2022-09-01      4.862        -0.015191        2.362    318.374
# 2022-10-01      4.836        -0.005348        2.386    319.917
# 2022-11-01      4.853         0.003515        2.419    320.034
# 2022-12-01      4.800        -0.010921        2.419    322.507
#
#             Milk Cost per Gallon  DJIA_change Next_Month_DJIA_Change
# date_time
# 2022-03-01                 3.917            1                      0
# 2022-04-01                 4.012            0                      1
# 2022-05-01                 4.204            1                      0
# 2022-06-01                 4.153            0                      1
# 2022-07-01                 4.156            1                      0
# 2022-08-01                 4.194            0                      0
# 2022-09-01                 4.181            0                      1
# 2022-10-01                 4.184            1                      1
# 2022-11-01                 4.218            1                      0
# 2022-12-01                 4.211            0                      1

# %%
# Drop unneeded DJIA_change column
next_month_df = price_df.drop("DJIA_change", axis=1)
next_month_df.head()
# Out:
#             Beef $/LB  Beef_Pct_Change  Wheat_Price  CPI_Price  \
# date_time
# 1995-07-01      1.365         0.024006        1.147      138.2
# 1995-08-01      1.328        -0.027106        1.161      138.8
# 1995-09-01      1.376         0.036145        1.159      139.5
# 1995-10-01      1.371        -0.003634        1.175      140.6
# 1995-11-01      1.368        -0.002188        1.169      141.0
#
#             Milk Cost per Gallon Next_Month_DJIA_Change
# date_time
# 1995-07-01                 2.477                      0
# 1995-08-01                 2.482                      1
# 1995-09-01                 2.459                      0
# 1995-10-01                 2.473                      1
# 1995-11-01                 2.493                      1

# %%
# Save this data as new CSV file
output_path = "ML1_pred_data.csv"
next_month_df.to_csv(output_path)
