# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
beef_df = pd.read_csv("../Edited Data/Output/FRED_beef_cleaned.csv")
djia_df = pd.read_csv("../Edited Data/Output/cleaned_djia.csv")

# %%
beef_df.head()
# Out:
#     date_time  Beef $/LB
# 0  1990-01-01      1.557
# 1  1990-02-01      1.572
# 2  1990-03-01      1.571
# 3  1990-04-01      1.593
# 4  1990-05-01      1.577

# %%
djia_df.head()
# Out:
#     date_time  DJIA_Price  DJIA_Open  DJIA_High  DJIA_Low  DJIA_Volume  \
# 0  2023-03-01    32930.14   32656.37   32973.59  32500.84          NaN
# 1  2023-02-01    32654.98   34039.60   34333.87  32638.35          NaN
# 2  2023-01-01    34086.89   33225.61   34342.28  32812.33          NaN
# 3  2022-12-01    33147.28   34533.59   34711.63  32573.43          NaN
# 4  2022-11-01    34587.46   32927.61   34587.46  31728.85          NaN
#
#    DJIA_Change_Percent
# 0                 0.84
# 1                -4.20
# 2                 2.83
# 3                -4.16
# 4                 5.66

# %%
djia_df_asc = djia_df.sort_values("date_time")
djia_df_asc.head()
# Out:
#       date_time  DJIA_Price  DJIA_Open  DJIA_High  DJIA_Low  DJIA_Volume  \
# 458  1990-01-01     2590.54    2753.41    2822.95   2519.14  474840000.0
# 457  1990-01-02     2590.54    2748.72    2834.04   2513.06   22610000.0
# 456  1990-02-01     2627.25    2590.32    2664.86   2548.42  354110000.0
# 455  1990-03-01     2707.21    2627.70    2768.24   2618.47  428160000.0
# 454  1990-04-01     2656.76    2706.76    2782.88   2634.01  422220000.0
#
#      DJIA_Change_Percent
# 458                -5.91
# 457                 0.00
# 456                 1.42
# 455                 3.04
# 454                -1.86

# %%
# Adapted from documentation
# https://matplotlib.org/stable/gallery/subplots_axes_and_figures/two_scales.html

t = beef_df["date_time"].values

fig, ax1 = plt.subplots()

color = 'tab:red'
ax1.set_xlabel('time (months)')
ax1.set_ylabel('$/LB Beef', color=color)
ax1.plot(t, beef_df["Beef $/LB"], color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel("DJIA Price", color=color)  # we already handled the x-label with ax1
ax2.plot(djia_df_asc["date_time"].values, djia_df_asc["DJIA_Price"], color=color)
ax2.tick_params(axis='y', labelcolor=color)

fig.tight_layout()  # otherwise the right y-label is slightly clipped
fig.set_size_inches(12, 9)
plt.show()
